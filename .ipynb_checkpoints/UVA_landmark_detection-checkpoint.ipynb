# %% [markdown]
# # CODEATHON 2: Recognizing UVA landmarks with neural nets (50 pts)
# ![UVA Grounds](http://faculty.virginia.edu/lazzara/images/UVAgrounds.jpg)
#
# The UVA Grounds is known for its Jeffersonian architecture and place in U.S. history as a model for college and university campuses throughout the country. Throughout its history, the University of Virginia has won praises for its unique Jeffersonian architecture.
#
# In this codeathon, you will attempt the build an image recognition system to classify different buildlings/landmarks on Grounds. You will earn 50 points for this codeathon plus 10 bonus points if (1) your classifier performs exceed 95% accuracy OR you try at least 3 different architectures and able to analyze their performance.
#
# To make it easier for you, some codes have been provided to help you process the data, you may modify it to fit your needs. You must submit the .ipynb file via UVA Collab with the following format: yourcomputingID_codeathon_2.ipynb
#
# Best of luck, and have fun!

# %% [markdown]
# # Load Packages

# %%
import sys
import sklearn
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from functools import partial

# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow import keras

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # Import Dataset
# The full dataset is huge (+37GB) with +13K images of 18 classes. So it will take a while to download, extract, and process. To save you time and effort, a subset of the data has been resized and compressed to only 379Mb and stored in my Firebase server. This dataset will be the one you will benchmark for your grade. If you are up for a challenge (and perhaps bonus points), contact the instructor for the full dataset!

# %%
# Download dataset from Firebase
# !wget https://firebasestorage.googleapis.com/v0/b/uva-landmark-images.appspot.com/o/dataset.zip?alt=media&token=e1403951-30d6-42b8-ba4e-394af1a2ddb7
# Out:
# --2021-04-23 01:05:12--  https://firebasestorage.googleapis.com/v0/b/uva-landmark-images.appspot.com/o/dataset.zip?alt=media
# Resolving firebasestorage.googleapis.com (firebasestorage.googleapis.com)... 74.125.142.95, 2607:f8b0:400e:c05::5f
# Connecting to firebasestorage.googleapis.com (firebasestorage.googleapis.com)|74.125.142.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 397174132 (379M) [application/zip]
# Saving to: ‘dataset.zip?alt=media’
#
# dataset.zip?alt=med 100%[===================>] 378.77M  60.7MB/s    in 6.2s
#
# 2021-04-23 01:05:19 (60.7 MB/s) - ‘dataset.zip?alt=media’ saved [397174132/397174132]

# %%
# Extract content
# !unzip "/content/dataset.zip?alt=media"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/Rotunda/0000010694.jpg
#   inflating: __MACOSX/dataset/Rotunda/._0000010694.jpg
#   inflating: dataset/Rotunda/0000010680.jpg
#   inflating: __MACOSX/dataset/Rotunda/._0000010680.jpg
#   inflating: dataset/Rotunda/0000010858.jpg
#   inflating: __MACOSX/dataset/Rotunda/._0000010858.jpg
#   inflating: dataset/Rotunda/0000010870.jpg
#   inflating: __MACOSX/dataset/Rotunda/._0000010870.jpg
#   inflating: dataset/Rotunda/0000010864.jpg
#   inflating: __MACOSX/dataset/Rotunda/._0000010864.jpg
#   inflating: dataset/Rotunda/0000010865.jpg
#   inflating: __MACOSX/dataset/Rotunda/._0000010865.jpg
#   inflating: dataset/Rotunda/0000010871.jpg
#   inflating: __MACOSX/dataset/Rotunda/._0000010871.jpg
#   inflating: dataset/Rotunda/0000010859.jpg
#   inflating: __MACOSX/dataset/Rotunda/._0000010859.jpg
#   inflating: dataset/Rotunda/0000010681.jpg
#   inflating: __MACOSX/dataset/Rotunda/._0000010681.jpg
# ...

# %%
from sklearn.datasets import load_files 
from keras.utils import np_utils

from keras.preprocessing import image
from tqdm import tqdm # progress bar

data_dir = "/content/dataset/"
batch_size = 32;
# IMPORTANT: Depends on what pre-trained model you choose, you will need to change these dimensions accordingly
img_height = 224; 
img_width = 224;

# Training Dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split = 0.2,
    subset = "training",
    seed = 42,
    image_size= (img_height, img_width),
    batch_size = batch_size
)

# Validation Dataset
validation_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split = 0.2,
    subset = "validation",
    seed = 42,
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 14286 files belonging to 18 classes.
# Using 11429 files for training.
# Found 14286 files belonging to 18 classes.
# Using 2857 files for validation.

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.dataset_ops.BatchDataset

# %%
# Visualize some of the train samples of one batch
# Make sure you create the class names that match the order of their appearances in the "files" variable
class_names = ['AcademicalVillage', 'AldermanLibrary', 'AlumniHall', 'AquaticFitnessCenter', 
  'BavaroHall', 'BrooksHall', 'ClarkHall', 'MadisonHall', 'MinorHall', 'NewCabellHall', 
  'NewcombHall', 'OldCabellHall', 'OlssonHall', 'RiceHall', 'Rotunda', 'ScottStadium', 
  'ThorntonHall', 'UniversityChapel']

# Rows and columns are set to fit one training batch (32)
n_rows = 8
n_cols = 4
plt.figure(figsize=(n_cols * 3, n_rows * 3))
for images, labels in train_ds.take(1):
    for i in range (n_rows*n_cols):
        plt.subplot(n_rows, n_cols, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis('off')
        plt.title(class_names[labels[i]], fontsize=12)
plt.subplots_adjust(wspace=.2, hspace=.2)

# %% [markdown]
# # It's your turn: Building a classifier for UVA Landmark Dataset
# You may design your own architecture AND re-use at least 2 of any of the pre-trained frameworks.
#
# Report the performance of these architectures. If at least one of your networks achieves a accuracy of 94% or above on the validation set, you will recieve a 10 bonus points!
#
# Best of luck!

# %%
n_classes = 18
dataset_size = 14286

# %% [markdown]
# ## MobileNetV2 Model

# %%
def preprocess_mobile(image, label):
  ret_image = keras.applications.mobilenet_v2.preprocess_input(image)
  return ret_image, label

mobile_base_model = keras.applications.MobileNetV2(input_shape=(224, 224, 3), weights='imagenet', include_top=False)
mobile_base_model.trainable = False

mobile_model = tf.keras.Sequential([
    mobile_base_model,
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(n_classes, activation="softmax")
])

train_ds_mobile = train_ds.map(partial(preprocess_mobile))
validation_ds_mobile = validation_ds.map(preprocess_mobile)

mobile_model.compile(loss="sparse_categorical_crossentropy", optimizer=keras.optimizers.Adam(lr=0.001), metrics=["accuracy"])
mobile_history = mobile_model.fit(train_ds_mobile, validation_data=validation_ds_mobile, epochs=30)
# Out:
# Epoch 1/30
# 358/358 [==============================] - 68s 100ms/step - loss: 1.8471 - accuracy: 0.4662 - val_loss: 0.9212 - val_accuracy: 0.7567
# Epoch 2/30
# 358/358 [==============================] - 35s 97ms/step - loss: 0.8337 - accuracy: 0.7706 - val_loss: 0.7269 - val_accuracy: 0.8040
# Epoch 3/30
# 358/358 [==============================] - 35s 97ms/step - loss: 0.6860 - accuracy: 0.8117 - val_loss: 0.6739 - val_accuracy: 0.8148
# Epoch 4/30
# 358/358 [==============================] - 35s 97ms/step - loss: 0.5963 - accuracy: 0.8352 - val_loss: 0.6085 - val_accuracy: 0.8344
# Epoch 5/30
# 358/358 [==============================] - 35s 98ms/step - loss: 0.5245 - accuracy: 0.8577 - val_loss: 0.6013 - val_accuracy: 0.8344
# Epoch 6/30
# 358/358 [==============================] - 35s 96ms/step - loss: 0.4921 - accuracy: 0.8668 - val_loss: 0.5624 - val_accuracy: 0.8488
# Epoch 7/30
# ...

# %%
mobile_base_model.trainable = True

mobile_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(lr=0.0001), metrics=["accuracy"])
mobile_model.fit(train_ds_mobile, validation_data=validation_ds_mobile, initial_epoch=mobile_history.epoch[-1], epochs=60)
# Out:
# Epoch 30/60
# 358/358 [==============================] - 84s 223ms/step - loss: 1.1711 - accuracy: 0.7244 - val_loss: 1.1357 - val_accuracy: 0.8141
# Epoch 31/60
# 358/358 [==============================] - 78s 218ms/step - loss: 0.2248 - accuracy: 0.9390 - val_loss: 0.7680 - val_accuracy: 0.8722
# Epoch 32/60
# 358/358 [==============================] - 80s 222ms/step - loss: 0.1051 - accuracy: 0.9687 - val_loss: 0.6042 - val_accuracy: 0.8957
# Epoch 33/60
# 358/358 [==============================] - 80s 221ms/step - loss: 0.0751 - accuracy: 0.9744 - val_loss: 0.5340 - val_accuracy: 0.9055
# Epoch 34/60
# 358/358 [==============================] - 79s 221ms/step - loss: 0.0482 - accuracy: 0.9863 - val_loss: 0.4469 - val_accuracy: 0.9223
# Epoch 35/60
# 358/358 [==============================] - 79s 219ms/step - loss: 0.0350 - accuracy: 0.9893 - val_loss: 0.4275 - val_accuracy: 0.9275
# Epoch 36/60
# ...

# %%
print('MobileNet Accuracy:', round(mobile_model.evaluate(validation_ds_mobile)[1] * 100, 2))
# Out:
# 90/90 [==============================] - 7s 75ms/step - loss: 0.5556 - accuracy: 0.9265
# MobileNet Accuracy: 92.65

# %% [markdown]
# ## InceptionResNetV2 Model

# %%
def preprocess_inception(image, label):
  new_image = tf.image.resize(image, [150, 150])
  ret_image = keras.applications.inception_resnet_v2.preprocess_input(new_image)
  return ret_image, label

inc_base_model = keras.applications.InceptionResNetV2(input_shape=(150, 150, 3), weights='imagenet', include_top=False)
inc_base_model.trainable = False

inc_model = tf.keras.Sequential([
    inc_base_model,
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(n_classes, activation="softmax")
])

train_ds_inc = train_ds.map(partial(preprocess_inception))
validation_ds_inc = validation_ds.map(preprocess_inception)

inc_model.compile(loss="sparse_categorical_crossentropy", optimizer=keras.optimizers.Adam(lr=0.001), metrics=["accuracy"])
inc_history = inc_model.fit(train_ds_inc, validation_data=validation_ds_inc, epochs=30)
# Out:
# ...
# 219062272/219055592 [==============================] - 4s 0us/step
# Epoch 1/30
# 358/358 [==============================] - 104s 174ms/step - loss: 2.2565 - accuracy: 0.3773 - val_loss: 1.2873 - val_accuracy: 0.6475
# Epoch 2/30
# 358/358 [==============================] - 59s 164ms/step - loss: 1.3433 - accuracy: 0.6105 - val_loss: 1.1801 - val_accuracy: 0.6629
# Epoch 3/30
# 358/358 [==============================] - 59s 164ms/step - loss: 1.1512 - accuracy: 0.6689 - val_loss: 1.0357 - val_accuracy: 0.7074
# Epoch 4/30
# 358/358 [==============================] - 59s 163ms/step - loss: 1.0421 - accuracy: 0.6989 - val_loss: 0.9626 - val_accuracy: 0.7375
# Epoch 5/30
# 358/358 [==============================] - 59s 164ms/step - loss: 0.9816 - accuracy: 0.7149 - val_loss: 0.9465 - val_accuracy: 0.7413
# Epoch 6/30
# 358/358 [==============================] - 59s 165ms/step - loss: 0.9616 - accuracy: 0.7186 - val_loss: 0.9510 - val_accuracy: 0.7350
# Epoch 7/30
# ...

# %%
inc_base_model.trainable = True

inc_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(lr=0.0001), metrics=["accuracy"])
inc_model.fit(train_ds_inc, validation_data=validation_ds_inc, initial_epoch=inc_history.epoch[-1], epochs=60)
# Out:
# Epoch 30/60
# 358/358 [==============================] - 143s 352ms/step - loss: 0.5666 - accuracy: 0.8476 - val_loss: 0.4051 - val_accuracy: 0.9037
# Epoch 31/60
# 358/358 [==============================] - 124s 345ms/step - loss: 0.1158 - accuracy: 0.9683 - val_loss: 0.5496 - val_accuracy: 0.9153
# Epoch 32/60
# 358/358 [==============================] - 124s 346ms/step - loss: 0.0427 - accuracy: 0.9884 - val_loss: 0.5225 - val_accuracy: 0.9244
# Epoch 33/60
# 358/358 [==============================] - 125s 348ms/step - loss: 0.0300 - accuracy: 0.9918 - val_loss: 0.4471 - val_accuracy: 0.9209
# Epoch 34/60
# 358/358 [==============================] - 125s 348ms/step - loss: 0.0454 - accuracy: 0.9870 - val_loss: 1.1423 - val_accuracy: 0.9142
# Epoch 35/60
# 358/358 [==============================] - 125s 347ms/step - loss: 0.0525 - accuracy: 0.9880 - val_loss: 0.4913 - val_accuracy: 0.9153
# Epoch 36/60
# ...

# %%
print('InceptionV3 accuracy:', round(inc_model.evaluate(validation_ds_inc)[1] * 100, 2))
# Out:
# 90/90 [==============================] - 12s 127ms/step - loss: 0.4304 - accuracy: 0.9492
# InceptionV3 accuracy: 94.92

# %% [markdown]
# ## My Own Architecture

# %%
data_augmentation = tf.keras.Sequential([
  keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  keras.layers.experimental.preprocessing.RandomRotation((-1./8, 1./8)),
])

model = keras.models.Sequential([
    data_augmentation,
    keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(224, 224, 3)),
    keras.layers.Conv2D(32, kernel_size=5, padding="same", activation="relu"),
    keras.layers.MaxPool2D(),
    keras.layers.Conv2D(32, kernel_size=3, padding="same", activation="relu"),
    keras.layers.MaxPool2D(),
    keras.layers.Conv2D(32, kernel_size=3, padding="same", activation="relu"),
    keras.layers.MaxPool2D(),
    keras.layers.Conv2D(32, kernel_size=3, padding="same", activation="relu"),
    keras.layers.MaxPool2D(),
    keras.layers.Dropout(0.2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dense(n_classes, activation="softmax")
])

model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(lr=0.001), metrics=["accuracy"])
model.fit(train_ds, epochs=30, validation_data=validation_ds)
# Out:
# Epoch 1/30
# 358/358 [==============================] - 37s 100ms/step - loss: 2.7851 - accuracy: 0.1156 - val_loss: 2.5836 - val_accuracy: 0.1848
# Epoch 2/30
# 358/358 [==============================] - 36s 98ms/step - loss: 2.5275 - accuracy: 0.2190 - val_loss: 2.1790 - val_accuracy: 0.3416
# Epoch 3/30
# 358/358 [==============================] - 36s 99ms/step - loss: 2.1096 - accuracy: 0.3557 - val_loss: 1.9189 - val_accuracy: 0.4256
# Epoch 4/30
# 358/358 [==============================] - 37s 102ms/step - loss: 1.8634 - accuracy: 0.4379 - val_loss: 1.7080 - val_accuracy: 0.4949
# Epoch 5/30
# 358/358 [==============================] - 36s 99ms/step - loss: 1.7032 - accuracy: 0.4871 - val_loss: 1.5822 - val_accuracy: 0.5313
# Epoch 6/30
# 358/358 [==============================] - 36s 99ms/step - loss: 1.6192 - accuracy: 0.5089 - val_loss: 1.5646 - val_accuracy: 0.5352
# Epoch 7/30
# ...

# %%
print('My model accuracy:', round(model.evaluate(validation_ds)[1] * 100, 2))
# Out:
# 90/90 [==============================] - 6s 65ms/step - loss: 1.0090 - accuracy: 0.7301
# My model accuracy: 73.01

# %% [markdown]
# I learned quite a lot about neural networks and deep learning through this assignment. I learned that small changes to a neural network can impact the overall results of the prediction pretty drastically, so we need to be precise with how we design our networks.
#
# As a part of this assignment, I choose to use the ModelNetV2 and InceptionResNetV2 pre-trained models. I chose those two models because I learned that they had pretty high accuracies through some online research. Also, in the model that I designed myself, I added a data augmentation layer, where it randomly flipped and rotated the images coming into the network because I wanted to experiement with ways to expand my training data and get a higher validation accuracy. Without the data augmentation, on my own network, I was achieving around 65% validation accuracy. At the end of the day, I was able to achieve these accuracies in the three models I implemented:
#
# 1.   ModelNetV2 - 92.65%
# 2.   InceptionResNetV2 - 94.92%
# 3.   My Model - 73.01%
